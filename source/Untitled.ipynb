# %%
import pandas as pd

# %%
df_code = pd.read_csv('ProjectData/법정동코드 조회자료.csv', encoding='cp949')
df_code
# Out:
#            법정동코드           법정동명 폐지구분
# 0     1100000000          서울특별시   현존
# 1     1111000000      서울특별시 종로구   현존
# 2     1111010100  서울특별시 종로구 청운동   현존
# 3     1111010200  서울특별시 종로구 신교동   현존
# 4     1111010300  서울특별시 종로구 궁정동   현존
# ...          ...            ...  ...
# 1107  1174010600  서울특별시 강동구 둔촌동   현존
# 1108  1174010700  서울특별시 강동구 암사동   현존
# 1109  1174010800  서울특별시 강동구 성내동   현존
# 1110  1174010900  서울특별시 강동구 천호동   현존
# 1111  1174011000  서울특별시 강동구 강일동   현존
#
# [1112 rows x 3 columns]

# %%
df_code.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1112 entries, 0 to 1111
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   법정동코드   1112 non-null   int64
#  1   법정동명    1112 non-null   object
#  2   폐지구분    1112 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 26.2+ KB

# %%
df_code.loc[df_code['법정동코드'] == 1111010100,'법정동명']
# Out:
# 2    서울특별시 종로구 청운동
# Name: 법정동명, dtype: object
