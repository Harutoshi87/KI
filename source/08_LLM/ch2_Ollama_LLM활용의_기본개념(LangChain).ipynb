# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:99% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:12pt;}
div.text_cell_render.rendered_html{font-size:20pt;}
div.text_cell_render ul li, div.text_cell_render ol li p, code{font-size:22pt; line-height:30px;}
div.output {font-size:12pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:12pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:12px;}
</style>
"""))
# Out:
# <style>
# div.container{width:99% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:12pt;}
# div.text_cell_render.rendered_html{font-size:20pt;}
# div.text_cell_render ul li, div.text_cell_render ol li p, code{font-size:22pt; line-height:30px;}
# div.output {font-size:12pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:12pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:12px;}
# </style>

# %% [markdown]
# # <span style="color:red">ch2_Ollama_LLM활용의_기본개념(LangChain)</span>
# # 1. LLM을 활용하여 답변 생성하기
# ## 1) Ollama를 이용한 local LLM 활용
# - 성능은 GPT, Claude 같은 모델보다 떨어지나 개념 설명을 위하여 open source 모델 사용
#
# ### ollama.com 다운로드 -> 설치 -> 모델 pull
# - cmd 창이나 powershell 창에 ollama pull/run deepseek-r1:1.5b
# https://docs.langchain.com/oss/python/integrations/chat/ollama

# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(model='deepseek-r1:1.5b')
result = llm.invoke('Where is the capital of Korea?')
result
# Out:
# AIMessage(content='The capital of Korea is Seoul.', additional_kwargs={}, response_metadata={'model': 'deepseek-r1:1.5b', 'created_at': '2025-12-09T02:05:09.4118724Z', 'done': True, 'done_reason': 'stop', 'total_duration': 571215700, 'load_duration': 84282600, 'prompt_eval_count': 10, 'prompt_eval_duration': 123379900, 'eval_count': 12, 'eval_duration': 346658800, 'logprobs': None, 'model_name': 'deepseek-r1:1.5b', 'model_provider': 'ollama'}, id='lc_run--019b00da-f75d-7c72-999f-49b90f0fc14f-0', usage_metadata={'input_tokens': 10, 'output_tokens': 12, 'total_tokens': 22})

# %% [markdown]
# ### 모델 pull
# - cmd 창이나 powershell(window키+R에서 powershell) 창에서 ollama pull llama3.2:1b

# %%
llm = ChatOllama(model='llama3.2:1b')
result = llm.invoke('Where is the capital of Korea?')
result
# Out:
# AIMessage(content='The capital of South Korea is Seoul.', additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2025-12-09T02:18:31.1938818Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1913003500, 'load_duration': 1322849900, 'prompt_eval_count': 32, 'prompt_eval_duration': 247386100, 'eval_count': 9, 'eval_duration': 332022400, 'logprobs': None, 'model_name': 'llama3.2:1b', 'model_provider': 'ollama'}, id='lc_run--019b00e7-2e1e-78a1-9bed-99b1dfc46e9b-0', usage_metadata={'input_tokens': 32, 'output_tokens': 9, 'total_tokens': 41})

# %%
result.content
# Out:
# 'The capital of South Korea is Seoul.'

# %%
result = llm.invoke('한국의 수도는?')
result.content
# Out:
# '수도는 Seoul입니다.'

# %% [markdown]
# ## 2) OpenAI 활용
# - pip install langchain-openai
# - https://auth.openai.com/log-in

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model='gpt-5-nano')
result = llm.invoke('Where is the capital of Korea? Return only the name of the city in Korean.')
