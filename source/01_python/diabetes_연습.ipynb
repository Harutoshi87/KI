# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:90% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:12pt;}
div.text_cell_render.rendered_html{font-size:12pt;}
div.output {font-size:12pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:12pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:12px;}
</style>
"""))
# Out:
# <style>
# div.container{width:90% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:12pt;}
# div.text_cell_render.rendered_html{font-size:12pt;}
# div.output {font-size:12pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:12pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:12px;}
# </style>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import datasets

# %%
# 시각화의 선명도를 높임
# %config InlineBackend.figure_format = "retina"

# 한글설정
sns.set(style='white', rc={'figure.figsize':(12,3)})
plt.rc('font', family='Malgun Gothic') # 윈도우즈
plt.rc('axes', unicode_minus=False) # 축의 - 깨짐 방지

# 다른 폰트를 기본 폰트로 하려면
# from matplotlib.font_manager import FontProperties
# font_path = 'C:/Windows/Fonts/HMFMPYUN.TTF'
# font_prop = FontProperties(fname=font_path, size=10)
# plt.rc('font', family=font_prop.get_name())

# 다른 폰트를 기본 폰트로 하려면
 
# warning(경고) 안보이게
import warnings
warnings.filterwarnings(action='ignore')

# %%
diabetes = datasets.load_diabetes()
diabetes
# Out:
# {'data': array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#           0.01990749, -0.01764613],
#         [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#          -0.06833155, -0.09220405],
#         [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#           0.00286131, -0.02593034],
#         ...,
#         [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#          -0.04688253,  0.01549073],
#         [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#           0.04452873, -0.02593034],
#         [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#          -0.00422151,  0.00306441]]),
#  'target': array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#          69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#          68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#          87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
# ...

# %%
diabetes.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'DESCR', 'feature_names', 'data_filename', 'target_filename', 'data_module'])

# %%
diabetes.DESCR
# Out:
# '.. _diabetes_dataset:\n\nDiabetes dataset\n----------------\n\nTen baseline variables, age, sex, body mass index, average blood\npressure, and six blood serum measurements were obtained for each of n =\n442 diabetes patients, as well as the response of interest, a\nquantitative measure of disease progression one year after baseline.\n\n**Data Set Characteristics:**\n\n  :Number of Instances: 442\n\n  :Number of Attributes: First 10 columns are numeric predictive values\n\n  :Target: Column 11 is a quantitative measure of disease progression one year after baseline\n\n  :Attribute Information:\n      - age     age in years\n      - sex\n      - bmi     body mass index\n      - bp      average blood pressure\n      - s1      tc, total serum cholesterol\n      - s2      ldl, low-density lipoproteins\n      - s3      hdl, high-density lipoproteins\n      - s4      tch, total cholesterol / HDL\n      - s5      ltg, possibly log of serum triglycerides level\n      - s6      glu, blood sug
# ...

# %%
X = pd.DataFrame(diabetes.data, columns=diabetes.feature_names)
X.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641

# %%
y = pd.DataFrame(diabetes.target, columns=['target'])
y.head()
# Out:
#    target
# 0   151.0
# 1    75.0
# 2   141.0
# 3   206.0
# 4   135.0

# %%
diabetes_df = pd.concat((X, y), axis=1)
diabetes_df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6  target
# ...

# %%
diabetes_df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6',
#        'target'],
#       dtype='object')

# %%
diabetes_df.columns = ['나이', '성별', 'bmi', '혈압', 's1', 's2', 's3', 's4', 's5', 's6',
       '진행정도']
diabetes_df
# Out:
#            나이        성별       bmi        혈압        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6   진행정도
# ...

# %%
diabetes_df[diabetes_df['bmi'] <= diabetes_df['bmi'].mean()]
# Out:
#            나이        성별       bmi        혈압        s1        s2        s3  \
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# 5   -0.092695 -0.044642 -0.040696 -0.019442 -0.068991 -0.079288  0.041277
# 6   -0.045472  0.050680 -0.047163 -0.015999 -0.040096 -0.024800  0.000779
# ..        ...       ...       ...       ...       ...       ...       ...
# 435 -0.012780 -0.044642 -0.023451 -0.040099 -0.016704  0.004636 -0.017629
# 436 -0.056370 -0.044642 -0.074108 -0.050427 -0.024960 -0.047034  0.092820
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6   진행정도
# ...

# %%
diabetes_df.sort_index(axis=1)
# Out:
#           bmi        s1        s2        s3        s4        s5        s6  \
# 0    0.061696 -0.044223 -0.034821 -0.043401 -0.002592  0.019907 -0.017646
# 1   -0.051474 -0.008449 -0.019163  0.074412 -0.039493 -0.068332 -0.092204
# 2    0.044451 -0.045599 -0.034194 -0.032356 -0.002592  0.002861 -0.025930
# 3   -0.011595  0.012191  0.024991 -0.036038  0.034309  0.022688 -0.009362
# 4   -0.036385  0.003935  0.015596  0.008142 -0.002592 -0.031988 -0.046641
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.019662 -0.005697 -0.002566 -0.028674 -0.002592  0.031193  0.007207
# 438 -0.015906  0.049341  0.079165 -0.028674  0.034309 -0.018114  0.044485
# 439 -0.015906 -0.037344 -0.013840 -0.024993 -0.011080 -0.046883  0.015491
# 440  0.039062  0.016318  0.015283 -0.028674  0.026560  0.044529 -0.025930
# 441 -0.073030  0.083740  0.027809  0.173816 -0.039493 -0.004222  0.003064
#
#            나이        성별   진행정도        혈압
# ...

# %%
diabetes_df.describe(include='all')
# Out:
#                  나이            성별           bmi            혈압            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -2.511817e-19  1.230790e-17 -2.245564e-16 -4.797570e-17 -1.381499e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123988e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665608e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670422e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564379e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320436e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   3.918434e-17 -5.777179e-18 -9.042540e-18  9.293722e-17  1.130318e-17
# ...

# %%
diabetes_df.count()
# Out:
# 나이      442
# 성별      442
# bmi     442
# 혈압      442
# s1      442
# s2      442
# s3      442
# s4      442
# s5      442
# s6      442
# 진행정도    442
# dtype: int64

# %%
diabetes_df.isna().sum()
# Out:
# 나이      0
# 성별      0
# bmi     0
# 혈압      0
# s1      0
# s2      0
# s3      0
# s4      0
# s5      0
# s6      0
# 진행정도    0
# dtype: int64

# %%
diabetes_df.min()
# Out:
# 나이      -0.107226
# 성별      -0.044642
# bmi     -0.090275
# 혈압      -0.112399
# s1      -0.126781
# s2      -0.115613
# s3      -0.102307
# s4      -0.076395
# s5      -0.126097
# s6      -0.137767
# 진행정도    25.000000
# dtype: float64

# %%
diabetes_df.max()
# Out:
# 나이        0.110727
# 성별        0.050680
# bmi       0.170555
# 혈압        0.132044
# s1        0.153914
# s2        0.198788
# s3        0.181179
# s4        0.185234
# s5        0.133597
# s6        0.135612
# 진행정도    346.000000
# dtype: float64

# %%
diabetes_df.mean()
# Out:
# 나이     -2.511817e-19
# 성별      1.230790e-17
# bmi    -2.245564e-16
# 혈압     -4.797570e-17
# s1     -1.381499e-17
# s2      3.918434e-17
# s3     -5.777179e-18
# s4     -9.042540e-18
# s5      9.293722e-17
# s6      1.130318e-17
# 진행정도    1.521335e+02
# dtype: float64

# %%
diabetes_df.median()
# Out:
# 나이        0.005383
# 성별       -0.044642
# bmi      -0.007284
# 혈압       -0.005670
# s1       -0.004321
# s2       -0.003819
# s3       -0.006584
# s4       -0.002592
# s5       -0.001947
# s6       -0.001078
# 진행정도    140.500000
# dtype: float64

# %%
diabetes_df.std()
# Out:
# 나이       0.047619
# 성별       0.047619
# bmi      0.047619
# 혈압       0.047619
# s1       0.047619
# s2       0.047619
# s3       0.047619
# s4       0.047619
# s5       0.047619
# s6       0.047619
# 진행정도    77.093005
# dtype: float64

# %%
diabetes_df.var()
# Out:
# 나이         0.002268
# 성별         0.002268
# bmi        0.002268
# 혈압         0.002268
# s1         0.002268
# s2         0.002268
# s3         0.002268
# s4         0.002268
# s5         0.002268
# s6         0.002268
# 진행정도    5943.331348
# dtype: float64

# %%
diabetes_df.quantile()
# Out:
# 나이        0.005383
# 성별       -0.044642
# bmi      -0.007284
# 혈압       -0.005670
# s1       -0.004321
# s2       -0.003819
# s3       -0.006584
# s4       -0.002592
# s5       -0.001947
# s6       -0.001078
# 진행정도    140.500000
# Name: 0.5, dtype: float64

# %%
diabetes_df.corr()
# Out:
#             나이        성별       bmi        혈압        s1        s2        s3  \
# 나이    1.000000  0.173737  0.185085  0.335428  0.260061  0.219243 -0.075181
# 성별    0.173737  1.000000  0.088161  0.241010  0.035277  0.142637 -0.379090
# bmi   0.185085  0.088161  1.000000  0.395411  0.249777  0.261170 -0.366811
# 혈압    0.335428  0.241010  0.395411  1.000000  0.242464  0.185548 -0.178762
# s1    0.260061  0.035277  0.249777  0.242464  1.000000  0.896663  0.051519
# s2    0.219243  0.142637  0.261170  0.185548  0.896663  1.000000 -0.196455
# s3   -0.075181 -0.379090 -0.366811 -0.178762  0.051519 -0.196455  1.000000
# s4    0.203841  0.332115  0.413807  0.257650  0.542207  0.659817 -0.738493
# s5    0.270774  0.149916  0.446157  0.393480  0.515503  0.318357 -0.398577
# s6    0.301731  0.208133  0.388680  0.390430  0.325717  0.290600 -0.273697
# 진행정도  0.187889  0.043062  0.586450  0.441482  0.212022  0.174054 -0.394789
#
#             s4        s5        s6      진행정도
# ...

# %%
diabetes_df.rolling(5).mean()
# Out:
#            나이        성별       bmi        혈압        s1        s2        s3  \
# 0         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4    0.007563 -0.006513  0.001339 -0.004982 -0.016429 -0.009518 -0.005848
# ..        ...       ...       ...       ...       ...       ...       ...
# 437 -0.007694 -0.025577 -0.027331 -0.010490  0.000908 -0.002817  0.039804
# 438 -0.003335 -0.006513 -0.018493 -0.018065  0.001458  0.009020  0.009615
# 439  0.001751  0.012551 -0.021942 -0.016226 -0.007073  0.004072 -0.001430
# 440 -0.004788  0.012551 -0.009439 -0.007963 -0.000468  0.006202 -0.003639
# 441 -0.002609  0.012551 -0.009224 -0.014160  0.021272  0.021170  0.012560
#
#            s4        s5        s6   진행정도
# ...

# %%
diabetes_df.aggregate(['sum', 'mean'])
# Out:
#                 나이            성별           bmi            혈압            s1  \
# sum  -1.110223e-16  5.440093e-15 -9.925394e-14 -2.120526e-14 -6.106227e-15
# mean -2.511817e-19  1.230790e-17 -2.245564e-16 -4.797570e-17 -1.381499e-17
#
#                 s2            s3            s4            s5            s6  \
# sum   1.731948e-14 -2.553513e-15 -3.996803e-15  4.107825e-14  4.996004e-15
# mean  3.918434e-17 -5.777179e-18 -9.042540e-18  9.293722e-17  1.130318e-17
#
#               진행정도
# sum   67243.000000
# mean    152.133484

# %%
diabetes_df.agg({'나이':'sum', 'bmi':'mean'})
# Out:
# 나이    -1.110223e-16
# bmi   -2.245564e-16
# dtype: float64

# %%
diabetes_df.cov()
# Out:
#             나이        성별       bmi        혈압        s1        s2        s3  \
# 나이    0.002268  0.000394  0.000420  0.000761  0.000590  0.000497 -0.000170
# 성별    0.000394  0.002268  0.000200  0.000547  0.000080  0.000323 -0.000860
# bmi   0.000420  0.000200  0.002268  0.000897  0.000566  0.000592 -0.000832
# 혈압    0.000761  0.000547  0.000897  0.002268  0.000550  0.000421 -0.000405
# s1    0.000590  0.000080  0.000566  0.000550  0.002268  0.002033  0.000117
# s2    0.000497  0.000323  0.000592  0.000421  0.002033  0.002268 -0.000445
# s3   -0.000170 -0.000860 -0.000832 -0.000405  0.000117 -0.000445  0.002268
# s4    0.000462  0.000753  0.000938  0.000584  0.001229  0.001496 -0.001675
# s5    0.000614  0.000340  0.001012  0.000892  0.001169  0.000722 -0.000904
# s6    0.000684  0.000472  0.000881  0.000885  0.000739  0.000659 -0.000621
# 진행정도  0.689758  0.158085  2.152914  1.620722  0.778355  0.638967 -1.449309
#
#             s4        s5        s6         진행정도
# ...

# %%
plt.figure(figsize=(12, 3))
sns.heatmap(diabetes_df.corr(), vmin=-1, vmax=1, annot=True, fmt='.2f', cmap='Greens')
plt.show()

# %%
diabetes_df.groupby('진행정도', as_index=False).mean()
# Out:
#       진행정도        나이        성별       bmi        혈압        s1        s2  \
# 0     25.0 -0.016412 -0.044642 -0.010517  0.001215 -0.037344 -0.035760
# 1     31.0  0.001751 -0.044642 -0.008362 -0.064199 -0.038720 -0.024487
# 2     37.0 -0.027310 -0.044642 -0.063330 -0.050427 -0.089630 -0.104340
# 3     39.0  0.003567  0.003019 -0.032073 -0.036656 -0.000881 -0.019633
# 4     40.0 -0.001882 -0.044642 -0.038540  0.021872 -0.108893 -0.115613
# ..     ...       ...       ...       ...       ...       ...       ...
# 209  321.0  0.019913  0.050680  0.104809  0.070072 -0.035968 -0.026679
# 210  332.0  0.059871  0.050680  0.076786  0.025315  0.001183  0.016849
# 211  336.0  0.034443  0.050680  0.111276  0.076958 -0.031840 -0.033881
# 212  341.0  0.034443  0.050680  0.125287  0.028758 -0.053855 -0.012900
# 213  346.0 -0.049105 -0.044642  0.160855 -0.046985 -0.029088 -0.019790
#
#            s3        s4        s5        s6
# 0    0.011824 -0.039493 -0.021395 -0.034215
# ...

# %%
diabetes_df.pivot_table(index='진행정도', aggfunc='mean')
# Out:
#             bmi        s1        s2        s3        s4        s5        s6  \
# 진행정도
# 25.0  -0.010517 -0.037344 -0.035760  0.011824 -0.039493 -0.021395 -0.034215
# 31.0  -0.008362 -0.038720 -0.024487  0.004460 -0.039493 -0.064685 -0.054925
# 37.0  -0.063330 -0.089630 -0.104340  0.052322 -0.076395 -0.056153 -0.067351
# 39.0  -0.032073 -0.000881 -0.019633  0.094661 -0.057944 -0.066600  0.005135
# 40.0  -0.038540 -0.108893 -0.115613  0.022869 -0.076395 -0.046883  0.023775
# ...         ...       ...       ...       ...       ...       ...       ...
# 321.0  0.104809 -0.035968 -0.026679 -0.024993 -0.002592  0.003709  0.040343
# 332.0  0.076786  0.001183  0.016849 -0.054446  0.034309  0.029935  0.044485
# 336.0  0.111276 -0.031840 -0.033881 -0.021311 -0.002592  0.028020  0.073480
# 341.0  0.125287 -0.053855 -0.012900 -0.102307  0.108111  0.000272  0.027917
# 346.0  0.160855 -0.029088 -0.019790 -0.047082  0.034309  0.028020  0.011349
#
#              나이        성별        혈압
# 진행정도
# ...

# %%
dfm = diabetes_df.melt(id_vars=['진행정도'], var_name='변수명', value_name='값').sort_values(by='진행정도')
dfm.reset_index(drop=True, inplace=True)

# %%
dfm.head(15)
# Out:
#     진행정도  변수명         값
# 0   25.0   혈압  0.001215
# 1   25.0   s4 -0.039493
# 2   25.0   s2 -0.035760
# 3   25.0   s1 -0.037344
# 4   25.0   s3  0.011824
# 5   25.0   나이 -0.016412
# 6   25.0  bmi -0.010517
# 7   25.0   s6 -0.034215
# 8   25.0   s5 -0.021395
# 9   25.0   성별 -0.044642
# 10  31.0   s5 -0.064685
# 11  31.0   s1 -0.038720
# 12  31.0   s4 -0.039493
# 13  31.0   혈압 -0.064199
# 14  31.0  bmi -0.008362

# %%
dfp = dfm.pivot_table(index='진행정도', columns='변수명', values='값')

# %%
dfp.head()
# Out:
# 변수명        bmi        s1        s2        s3        s4        s5        s6  \
# 진행정도
# 25.0 -0.010517 -0.037344 -0.035760  0.011824 -0.039493 -0.021395 -0.034215
# 31.0 -0.008362 -0.038720 -0.024487  0.004460 -0.039493 -0.064685 -0.054925
# 37.0 -0.063330 -0.089630 -0.104340  0.052322 -0.076395 -0.056153 -0.067351
# 39.0 -0.032073 -0.000881 -0.019633  0.094661 -0.057944 -0.066600  0.005135
# 40.0 -0.038540 -0.108893 -0.115613  0.022869 -0.076395 -0.046883  0.023775
#
# 변수명         나이        성별        혈압
# 진행정도
# 25.0 -0.016412 -0.044642  0.001215
# 31.0  0.001751 -0.044642 -0.064199
# 37.0 -0.027310 -0.044642 -0.050427
# 39.0  0.003567  0.003019 -0.036656
# 40.0 -0.001882 -0.044642  0.021872

# %%
diabetes_df
# Out:
#            나이        성별       bmi        혈압        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6   진행정도
# ...

# %%
d_mean = diabetes_df.groupby('진행정도').mean()
d_mean = d_mean.reset_index()

# %%
d_mean
# Out:
#       진행정도        나이        성별       bmi        혈압        s1        s2  \
# 0     25.0 -0.016412 -0.044642 -0.010517  0.001215 -0.037344 -0.035760
# 1     31.0  0.001751 -0.044642 -0.008362 -0.064199 -0.038720 -0.024487
# 2     37.0 -0.027310 -0.044642 -0.063330 -0.050427 -0.089630 -0.104340
# 3     39.0  0.003567  0.003019 -0.032073 -0.036656 -0.000881 -0.019633
# 4     40.0 -0.001882 -0.044642 -0.038540  0.021872 -0.108893 -0.115613
# ..     ...       ...       ...       ...       ...       ...       ...
# 209  321.0  0.019913  0.050680  0.104809  0.070072 -0.035968 -0.026679
# 210  332.0  0.059871  0.050680  0.076786  0.025315  0.001183  0.016849
# 211  336.0  0.034443  0.050680  0.111276  0.076958 -0.031840 -0.033881
# 212  341.0  0.034443  0.050680  0.125287  0.028758 -0.053855 -0.012900
# 213  346.0 -0.049105 -0.044642  0.160855 -0.046985 -0.029088 -0.019790
#
#            s3        s4        s5        s6
# 0    0.011824 -0.039493 -0.021395 -0.034215
# ...

# %%
import random
for col in range(diabetes_df.shape[1]-1):
    diabetes_df.iloc[random.sample(range(442), 10), col] = np.nan
diabetes_df.iloc[::50]
# Out:
#            나이        성별       bmi        혈압        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 50   0.034443 -0.044642 -0.007284  0.014987 -0.044223 -0.037326 -0.002903
# 100  0.016281 -0.044642  0.017506 -0.022885  0.060349  0.044406  0.030232
# 150  0.023546 -0.044642  0.070319  0.025315 -0.034592 -0.014466 -0.032356
# 200  0.056239 -0.044642 -0.057941 -0.007977  0.052093  0.049103  0.056003
# 250  0.067136 -0.044642  0.056307  0.073515 -0.013953 -0.039205 -0.032356
# 300  0.016281 -0.044642  0.073552 -0.041235 -0.004321 -0.013527 -0.013948
# 350 -0.027310  0.050680  0.060618  0.107944       NaN -0.017598 -0.002903
# 400 -0.023677 -0.044642  0.045529  0.090729 -0.018080 -0.035447  0.070730
#
#            s4        s5        s6   진행정도
# 0   -0.002592  0.019907 -0.017646  151.0
# 50  -0.039493 -0.021395  0.007207  155.0
# 100 -0.002592  0.037236 -0.001078  128.0
# 150 -0.002592 -0.019198 -0.009362  288.0
# ...

# %%
np.where(diabetes_df.isna())
# Out:
# (array([ 10,  14,  18,  19,  29,  34,  35,  45,  51,  51,  52,  59,  63,
#          83,  94,  94,  95,  98, 107, 108, 108, 119, 125, 130, 130, 132,
#         133, 135, 136, 137, 146, 158, 163, 177, 178, 183, 184, 189, 191,
#         191, 193, 196, 197, 203, 213, 216, 217, 228, 228, 229, 231, 232,
#         240, 247, 248, 257, 264, 265, 266, 281, 282, 287, 288, 304, 305,
#         310, 314, 323, 338, 341, 346, 347, 348, 350, 358, 366, 367, 371,
#         380, 385, 388, 389, 390, 392, 394, 401, 403, 405, 405, 406, 409,
#         415, 415, 419, 426, 427, 428, 428, 434, 438], dtype=int64),
#  array([0, 6, 2, 9, 7, 5, 2, 6, 4, 5, 3, 8, 3, 2, 4, 9, 5, 3, 0, 7, 9, 2,
#         7, 3, 5, 3, 4, 6, 3, 7, 2, 6, 1, 7, 0, 7, 8, 1, 2, 8, 1, 8, 7, 3,
#         9, 5, 0, 1, 2, 9, 6, 5, 2, 1, 5, 0, 4, 8, 8, 4, 6, 9, 4, 4, 5, 0,
#         6, 5, 9, 1, 3, 8, 9, 4, 4, 8, 2, 0, 8, 7, 7, 1, 0, 0, 0, 9, 3, 1,
#         8, 1, 7, 6, 9, 4, 6, 6, 3, 5, 1, 2], dtype=int64))

# %%
d_mean = diabetes_df.groupby('진행정도').mean()

# %%
d_mean
# Out:
#              나이        성별       bmi        혈압        s1        s2        s3  \
# 진행정도
# 25.0  -0.016412 -0.044642 -0.010517  0.001215 -0.037344 -0.035760  0.011824
# 31.0   0.001751 -0.044642 -0.008362 -0.064199 -0.038720 -0.024487  0.004460
# 37.0  -0.027310 -0.044642 -0.063330 -0.050427 -0.089630 -0.104340  0.052322
# 39.0   0.003567  0.003019 -0.032073 -0.036656 -0.000881 -0.019633  0.094661
# 40.0  -0.001882 -0.044642 -0.038540  0.021872 -0.108893 -0.115613  0.022869
# ...         ...       ...       ...       ...       ...       ...       ...
# 321.0  0.019913  0.050680  0.104809  0.070072 -0.035968 -0.026679 -0.024993
# 332.0  0.059871  0.050680  0.076786  0.025315  0.001183  0.016849 -0.054446
# 336.0  0.034443  0.050680  0.111276  0.076958 -0.031840 -0.033881 -0.021311
# 341.0  0.034443  0.050680  0.125287  0.028758 -0.053855 -0.012900 -0.102307
# 346.0 -0.049105 -0.044642  0.160855 -0.046985 -0.029088 -0.019790 -0.047082
#
#              s4        s5        s6
# 진행정도
# ...

# %%
def fillna_gr_diabetes(series):
    'series의 결측치를 대체한 후 series return'
    series = series.copy() # 함수 안에서 series의 결측치를 대체하여 변경하기 위해
    for col, item in series.iloc[:-1].items():
        if np.isnan(item): # 스칼라 데이터가 결측치인지 여부
            row=series['진행정도']
            series[col] = d_mean.loc[row, col] # 진행정도별 열별 평균값 대체
    return series

# %%
fillna_gr_diabetes(diabetes_df.iloc[350])
# Out:
# 나이       -0.027310
# 성별        0.050680
# bmi       0.060618
# 혈압        0.107944
# s1        0.060349
# s2       -0.017598
# s3       -0.002903
# s4       -0.002592
# s5        0.070207
# s6        0.135612
# 진행정도    243.000000
# Name: 350, dtype: float64

# %%
diabetes_df = diabetes_df.apply(fillna_gr_diabetes, axis=1)

# %%
diabetes_df.iloc[10]
# Out:
# 나이       -0.069084
# 성별       -0.044642
# bmi      -0.083808
# 혈압        0.008101
# s1       -0.103389
# s2       -0.090561
# s3       -0.013948
# s4       -0.076395
# s5       -0.062917
# s6       -0.034215
# 진행정도    101.000000
# Name: 10, dtype: float64

# %%
diabetes_df.iloc[350]
# Out:
# 나이       -0.027310
# 성별        0.050680
# bmi       0.060618
# 혈압        0.107944
# s1        0.060349
# s2       -0.017598
# s3       -0.002903
# s4       -0.002592
# s5        0.070207
# s6        0.135612
# 진행정도    243.000000
# Name: 350, dtype: float64
